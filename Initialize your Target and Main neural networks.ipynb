# %%
# CartPole is one of the simplest environments in the OpenAI gym (a game simulator). 
# As you can see in the above animation, the goal of CartPole is to balance a pole that’s connected with one joint on top of a moving cart.
#Initialize your Target and Main neural networks
# It keeps on running like a ongoing video game as long as it is active it keeps playing, I have done till 393 times.
import gym
import random
import os
import numpy as np
from collections      import deque
from keras.models     import Sequential
from keras.layers     import Dense
from keras.optimizers import Adam

class Agent():
    def __init__(self, state_size, action_size):
        self.weight_backup      = "cartpole_weight.h5"
        self.state_size         = state_size
        self.action_size        = action_size
        self.memory             = deque(maxlen=2000)
        self.learning_rate      = 0.001
        self.gamma              = 0.95
        self.exploration_rate   = 1.0
        self.exploration_min    = 0.01
        self.exploration_decay  = 0.995
        self.brain              = self._build_model()

    def _build_model(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        model.add(Dense(24, input_dim=self.state_size, activation='relu'))
        model.add(Dense(24, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse', optimizer=Adam(lr=self.learning_rate))

        if os.path.isfile(self.weight_backup):
            model.load_weights(self.weight_backup)
            self.exploration_rate = self.exploration_min
        return model

    def save_model(self):
            self.brain.save(self.weight_backup)

    def act(self, state):
        if np.random.rand() <= self.exploration_rate:
            return random.randrange(self.action_size)
        act_values = self.brain.predict(state)
        return np.argmax(act_values[0])

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def replay(self, sample_batch_size):
        if len(self.memory) < sample_batch_size:
            return
        sample_batch = random.sample(self.memory, sample_batch_size)
        for state, action, reward, next_state, done in sample_batch:
            target = reward
            if not done:
              target = reward + self.gamma * np.amax(self.brain.predict(next_state)[0])
            target_f = self.brain.predict(state)
            target_f[0][action] = target
            self.brain.fit(state, target_f, epochs=1, verbose=0)
        if self.exploration_rate > self.exploration_min:
            self.exploration_rate *= self.exploration_decay

class CartPole:
    def __init__(self):
        self.sample_batch_size = 32
        self.episodes          = 10000
        self.env               = gym.make('CartPole-v1')

        self.state_size        = self.env.observation_space.shape[0]
        self.action_size       = self.env.action_space.n
        self.agent             = Agent(self.state_size, self.action_size)


    def run(self):
        try:
            for index_episode in range(self.episodes):
                state = self.env.reset()
                state = np.reshape(state, [1, self.state_size])

                done = False
                index = 0
                while not done:
#                    self.env.render()

                    action = self.agent.act(state)

                    next_state, reward, done, _ = self.env.step(action)
                    next_state = np.reshape(next_state, [1, self.state_size])
                    self.agent.remember(state, action, reward, next_state, done)
                    state = next_state
                    index += 1
                print("Episode {}# Score: {}".format(index_episode, index + 1))
                self.agent.replay(self.sample_batch_size)
        finally:
            self.agent.save_model()

if __name__ == "__main__":
    cartpole = CartPole()
    cartpole.run()
# Out:
# Episode 0# Score: 40
# Episode 1# Score: 12
# Episode 2# Score: 20
# Episode 3# Score: 14
# Episode 4# Score: 44
# Episode 5# Score: 14
# Episode 6# Score: 18
# Episode 7# Score: 12
# Episode 8# Score: 16
# Episode 9# Score: 18
# Episode 10# Score: 26
# Episode 11# Score: 15
# Episode 12# Score: 42
# Episode 13# Score: 18
# Episode 14# Score: 19
# Episode 15# Score: 62
# Episode 16# Score: 12
# Episode 17# Score: 35
# Episode 18# Score: 41
# Episode 19# Score: 18
# Episode 20# Score: 11
# Episode 21# Score: 25
# Episode 22# Score: 14
# Episode 23# Score: 15
# Episode 24# Score: 16
# Episode 25# Score: 17
# Episode 26# Score: 20
# Episode 27# Score: 18
# Episode 28# Score: 14
# Episode 29# Score: 12
# Episode 30# Score: 15
# Episode 31# Score: 16
# Episode 32# Score: 14
# Episode 33# Score: 17
# Episode 34# Score: 14
# Episode 35# Score: 21
# Episode 36# Score: 17
# Episode 37# Score: 32
# Episode 38# Score: 18
# Episode 39# Score: 22
# Episode 40# Score: 23
# Episode 41# Score: 17
# Episode 42# Score: 14
# Episode 43# Score: 13
# Episode 44# Score: 19
# Episode 45# Score: 15
# Episode 46# Score: 13
# Episode 47# Score: 13
# Episode 48# Score: 13
# Episode 49# Score: 11
# Episode 50# Score: 26
# Episode 51# Score: 15
# Episode 52# Score: 21
# Episode 53# Score: 13
# Episode 54# Score: 12
# Episode 55# Score: 16
# Episode 56# Score: 11
# Episode 57# Score: 16
# Episode 58# Score: 26
# Episode 59# Score: 24
# Episode 60# Score: 18
# Episode 61# Score: 13
# Episode 62# Score: 11
# Episode 63# Score: 27
# Episode 64# Score: 13
# Episode 65# Score: 52
# Episode 66# Score: 19
# Episode 67# Score: 10
# Episode 68# Score: 20
# Episode 69# Score: 18
# Episode 70# Score: 10
# Episode 71# Score: 19
# Episode 72# Score: 11
# Episode 73# Score: 16
# Episode 74# Score: 26
# Episode 75# Score: 16
# Episode 76# Score: 30
# Episode 77# Score: 12
# Episode 78# Score: 12
# Episode 79# Score: 16
# Episode 80# Score: 21
# Episode 81# Score: 18
# Episode 82# Score: 30
# Episode 83# Score: 30
# Episode 84# Score: 36
# Episode 85# Score: 21
# Episode 86# Score: 50
# Episode 87# Score: 72
# Episode 88# Score: 13
# Episode 89# Score: 13
# Episode 90# Score: 21
# Episode 91# Score: 25
# Episode 92# Score: 40
# Episode 93# Score: 18
# Episode 94# Score: 16
# Episode 95# Score: 14
# Episode 96# Score: 29
# Episode 97# Score: 23
# Episode 98# Score: 18
# Episode 99# Score: 13
# Episode 100# Score: 64
# Episode 101# Score: 127
# Episode 102# Score: 30
# Episode 103# Score: 17
# Episode 104# Score: 33
# Episode 105# Score: 24
# Episode 106# Score: 12
# Episode 107# Score: 60
# Episode 108# Score: 53
# Episode 109# Score: 29
# Episode 110# Score: 40
# Episode 111# Score: 17
# Episode 112# Score: 14
# Episode 113# Score: 23
# Episode 114# Score: 38
# Episode 115# Score: 16
# Episode 116# Score: 29
# Episode 117# Score: 52
# Episode 118# Score: 27
# Episode 119# Score: 18
# Episode 120# Score: 14
# Episode 121# Score: 21
# Episode 122# Score: 17
# Episode 123# Score: 30
# Episode 124# Score: 11
# Episode 125# Score: 12
# Episode 126# Score: 55
# Episode 127# Score: 106
# Episode 128# Score: 67
# Episode 129# Score: 54
# Episode 130# Score: 126
# Episode 131# Score: 76
# Episode 132# Score: 106
# Episode 133# Score: 69
# Episode 134# Score: 54
# Episode 135# Score: 58
# Episode 136# Score: 20
# Episode 137# Score: 46
# Episode 138# Score: 36
# Episode 139# Score: 163
# Episode 140# Score: 15
# Episode 141# Score: 171
# Episode 142# Score: 44
# Episode 143# Score: 12
# Episode 144# Score: 40
# Episode 145# Score: 96
# Episode 146# Score: 51
# Episode 147# Score: 185
# Episode 148# Score: 83
# Episode 149# Score: 83
# Episode 150# Score: 24
# Episode 151# Score: 55
# Episode 152# Score: 53
# Episode 153# Score: 19
# Episode 154# Score: 31
# Episode 155# Score: 55
# Episode 156# Score: 65
# Episode 157# Score: 91
# Episode 158# Score: 99
# Episode 159# Score: 79
# Episode 160# Score: 178
# Episode 161# Score: 183
# Episode 162# Score: 69
# Episode 163# Score: 82
# Episode 164# Score: 32
# Episode 165# Score: 80
# Episode 166# Score: 44
# Episode 167# Score: 37
# Episode 168# Score: 12
# Episode 169# Score: 44
# Episode 170# Score: 67
# Episode 171# Score: 37
# Episode 172# Score: 78
# Episode 173# Score: 94
# Episode 174# Score: 13
# Episode 175# Score: 25
# Episode 176# Score: 33
# Episode 177# Score: 58
# Episode 178# Score: 34
# Episode 179# Score: 27
# Episode 180# Score: 56
# Episode 181# Score: 71
# Episode 182# Score: 42
# Episode 183# Score: 44
# Episode 184# Score: 24
# Episode 185# Score: 36
# Episode 186# Score: 67
# Episode 187# Score: 55
# Episode 188# Score: 91
# Episode 189# Score: 102
# Episode 190# Score: 53
# Episode 191# Score: 77
# Episode 192# Score: 91
# Episode 193# Score: 115
# Episode 194# Score: 40
# Episode 195# Score: 56
# Episode 196# Score: 34
# Episode 197# Score: 51
# Episode 198# Score: 154
# Episode 199# Score: 26
# Episode 200# Score: 83
# Episode 201# Score: 37
# Episode 202# Score: 50
# Episode 203# Score: 34
# Episode 204# Score: 17
# Episode 205# Score: 54
# Episode 206# Score: 97
# Episode 207# Score: 49
# Episode 208# Score: 46
# Episode 209# Score: 127
# Episode 210# Score: 28
# Episode 211# Score: 21
# Episode 212# Score: 21
# Episode 213# Score: 17
# Episode 214# Score: 22
# Episode 215# Score: 14
# Episode 216# Score: 56
# Episode 217# Score: 84
# Episode 218# Score: 31
# Episode 219# Score: 69
# Episode 220# Score: 66
# Episode 221# Score: 35
# Episode 222# Score: 69
# Episode 223# Score: 30
# Episode 224# Score: 124
# Episode 225# Score: 47
# Episode 226# Score: 23
# Episode 227# Score: 60
# Episode 228# Score: 126
# Episode 229# Score: 33
# Episode 230# Score: 115
# Episode 231# Score: 76
# Episode 232# Score: 54
# Episode 233# Score: 18
# Episode 234# Score: 43
# Episode 235# Score: 46
# Episode 236# Score: 39
# Episode 237# Score: 103
# Episode 238# Score: 24
# Episode 239# Score: 31
# Episode 240# Score: 30
# Episode 241# Score: 84
# Episode 242# Score: 122
# Episode 243# Score: 58
# Episode 244# Score: 42
# Episode 245# Score: 53
# Episode 246# Score: 40
# Episode 247# Score: 65
# Episode 248# Score: 50
# Episode 249# Score: 36
# Episode 250# Score: 72
# Episode 251# Score: 33
# Episode 252# Score: 24
# Episode 253# Score: 29
# Episode 254# Score: 65
# Episode 255# Score: 62
# Episode 256# Score: 57
# Episode 257# Score: 47
# Episode 258# Score: 45
# Episode 259# Score: 41
# Episode 260# Score: 41
# Episode 261# Score: 67
# Episode 262# Score: 70
# Episode 263# Score: 67
# Episode 264# Score: 89
# Episode 265# Score: 53
# Episode 266# Score: 34
# Episode 267# Score: 51
# Episode 268# Score: 93
# Episode 269# Score: 29
# Episode 270# Score: 60
# Episode 271# Score: 37
# Episode 272# Score: 50
# Episode 273# Score: 44
# Episode 274# Score: 32
# Episode 275# Score: 37
# Episode 276# Score: 61
# Episode 277# Score: 58
# Episode 278# Score: 34
# Episode 279# Score: 57
# Episode 280# Score: 48
# Episode 281# Score: 53
# Episode 282# Score: 41
# Episode 283# Score: 42
# Episode 284# Score: 19
# Episode 285# Score: 62
# Episode 286# Score: 79
# Episode 287# Score: 35
# Episode 288# Score: 31
# Episode 289# Score: 29
# Episode 290# Score: 65
# Episode 291# Score: 58
# Episode 292# Score: 34
# Episode 293# Score: 22
# Episode 294# Score: 35
# Episode 295# Score: 57
# Episode 296# Score: 97
# Episode 297# Score: 121
# Episode 298# Score: 40
# Episode 299# Score: 47
# Episode 300# Score: 115
# Episode 301# Score: 47
# Episode 302# Score: 196
# Episode 303# Score: 44
# Episode 304# Score: 94
# Episode 305# Score: 52
# Episode 306# Score: 151
# Episode 307# Score: 68
# Episode 308# Score: 62
# Episode 309# Score: 92
# Episode 310# Score: 72
# Episode 311# Score: 34
# Episode 312# Score: 44
# Episode 313# Score: 59
# Episode 314# Score: 186
# Episode 315# Score: 47
# Episode 316# Score: 62
# Episode 317# Score: 73
# Episode 318# Score: 55
# Episode 319# Score: 32
# Episode 320# Score: 36
# Episode 321# Score: 55
# Episode 322# Score: 71
# Episode 323# Score: 38
# Episode 324# Score: 231
# Episode 325# Score: 83
# Episode 326# Score: 61
# Episode 327# Score: 82
# Episode 328# Score: 127
# Episode 329# Score: 67
# Episode 330# Score: 157
# Episode 331# Score: 63
# Episode 332# Score: 89
# Episode 333# Score: 80
# Episode 334# Score: 87
# Episode 335# Score: 151
# Episode 336# Score: 143
# Episode 337# Score: 50
# Episode 338# Score: 68
# Episode 339# Score: 32
# Episode 340# Score: 67
# Episode 341# Score: 117
# Episode 342# Score: 44
# Episode 343# Score: 43
# Episode 344# Score: 36
# Episode 345# Score: 72
# Episode 346# Score: 68
# Episode 347# Score: 98
# Episode 348# Score: 69
# Episode 349# Score: 90
# Episode 350# Score: 48
# Episode 351# Score: 35
# Episode 352# Score: 140
# Episode 353# Score: 104
# Episode 354# Score: 72
# Episode 355# Score: 70
# Episode 356# Score: 48
# Episode 357# Score: 38
# Episode 358# Score: 47
# Episode 359# Score: 78
# Episode 360# Score: 59
# Episode 361# Score: 54
# Episode 362# Score: 71
# Episode 363# Score: 31
# Episode 364# Score: 31
# Episode 365# Score: 68
# Episode 366# Score: 179
# Episode 367# Score: 33
# Episode 368# Score: 26
# Episode 369# Score: 40
# Episode 370# Score: 53
# Episode 371# Score: 29
# Episode 372# Score: 61
# Episode 373# Score: 89
# Episode 374# Score: 195
# Episode 375# Score: 24
# Episode 376# Score: 35
# Episode 377# Score: 26
# Episode 378# Score: 120
# Episode 379# Score: 36
# Episode 380# Score: 84
# Episode 381# Score: 138
# Episode 382# Score: 139
# Episode 383# Score: 34
# Episode 384# Score: 45
# Episode 385# Score: 35
# Episode 386# Score: 78
# Episode 387# Score: 55
# Episode 388# Score: 78
# Episode 389# Score: 63
# Episode 390# Score: 162
# Episode 391# Score: 140
# Episode 392# Score: 202
# Episode 393# Score: 51
